# %% [markdown]
# <a href="https://colab.research.google.com/github/pawan070bct27/Data_Analysis_Updated/blob/main/Data_Month1_Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORTING NECESSARY LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
import matplotlib
import pylab as pl
warnings.filterwarnings("ignore")

# %% [markdown]
# #LOADING THE DATASET

# %%
df = pd.read_csv('Project Data_ Month 1 - raw_data.csv',parse_dates=['date'])
df
# Out:
#              date   device  creative_id  ... impressions  referrals  conversions
# 0      2017-11-01  Desktop            6  ...          23          0            0
# 1      2017-11-01  Desktop           54  ...          63          1            0
# 2      2017-11-01  Desktop           55  ...         307         24            0
# 3      2017-11-01  Desktop           10  ...         241         15            0
# 4      2017-11-01   Mobile            6  ...        1272         42            0
# ...           ...      ...          ...  ...         ...        ...          ...
# 134616 2017-11-30   Tablet           10  ...          47          0            0
# 134617 2017-11-30   Tablet            6  ...         124          0            0
# 134618 2017-11-30   Tablet            6  ...          90          0            0
# 134619 2017-11-30   Tablet            1  ...         220          0            0
# 134620 2017-11-30   Tablet           57  ...          30          0            0
#
# [134621 rows x 8 columns]

# %% [markdown]
# #Describing the statistical property of each column of dataset

# %%
df.describe()
# Out:
#          creative_id  publisher_split  ...      referrals    conversions
# count  134621.000000    134621.000000  ...  134621.000000  134621.000000
# mean       26.213837         0.559933  ...       5.414920       0.015258
# std        22.962272         3.449313  ...      29.347153       0.152838
# min         1.000000         0.000000  ...       0.000000       0.000000
# 25%         6.000000         0.010000  ...       0.000000       0.000000
# 50%        11.000000         0.040000  ...       0.000000       0.000000
# 75%        54.000000         0.210000  ...       2.000000       0.000000
# max        58.000000       205.150000  ...    3393.000000       9.000000
#
# [8 rows x 5 columns]

# %% [markdown]
# # More information on columns of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134621 entries, 0 to 134620
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             134621 non-null  datetime64[ns]
#  1   device           134621 non-null  object
#  2   creative_id      134621 non-null  int64
#  3   ad_unit_id       134621 non-null  object
#  4   publisher_split  134621 non-null  float64
#  5   impressions      134621 non-null  int64
#  6   referrals        134621 non-null  int64
#  7   conversions      134621 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 8.2+ MB

# %% [markdown]
# # Finding the correlation relationship between each columns.

# %%
corr_relation = df.corr()
corr_relation
# Out:
#                  creative_id  publisher_split  ...  referrals  conversions
# creative_id         1.000000         0.030302  ...   0.034203     0.016585
# publisher_split     0.030302         1.000000  ...   0.753557     0.505374
# impressions         0.010057         0.443200  ...   0.382681     0.251674
# referrals           0.034203         0.753557  ...   1.000000     0.521425
# conversions         0.016585         0.505374  ...   0.521425     1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# #Let's visualize the correlation between each columns.

# %%
# visualization
fig = plt.figure(figsize=(8,8))
plt.matshow(corr_relation, cmap = 'RdBu',fignum= fig.number)
plt.xticks(range(len(corr_relation.columns)), corr_relation.columns, rotation = 'vertical')
plt.yticks(range(len(corr_relation.columns)), corr_relation.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7f21f8e993c8>,
#   <matplotlib.axis.YTick at 0x7f21f85f3a90>,
#   <matplotlib.axis.YTick at 0x7f21f85f30b8>,
#   <matplotlib.axis.YTick at 0x7f21f85bba58>,
#   <matplotlib.axis.YTick at 0x7f21f85bbef0>],
#  [Text(0, 0, 'creative_id'),
#   Text(0, 0, 'publisher_split'),
#   Text(0, 0, 'impressions'),
#   Text(0, 0, 'referrals'),
#   Text(0, 0, 'conversions')])

# %% [markdown]
# In the figure above Dark blue represents the highest correlation and dark red represents the lowest correlation.
# From the above figure we can make following observation:
#
# * Creative id and conversions has very weak correlation. That is the they are almost independent to each other without any relationship. Let's explore them below:

# %% [markdown]
# #Comparison of impressions, referrals and conversions with respect to the device type.

# %%
# Creation of new DataFrame
new_df_rows = []
for device in df['device'].unique():
  rows = df[df['device'] == device]
  total_conversions = rows['conversions'].sum()
  total_impressions = rows['impressions'].sum()
  total_referrals  = rows['referrals'].sum()
  new_df_rows.append([device,'conversions',total_conversions])
  new_df_rows.append([device,'impressions',total_impressions])
  new_df_rows.append([device,'referrals',total_referrals])

# Normalization of frequency, using logarithmic function, for clear visibility of graph 
new_df = pd.DataFrame(new_df_rows, columns=['Device', 'Action Type', 'Frequency'])
new_df['log(Frequency)'] = np.log10(new_df['Frequency'])
print(new_df)

#Visualization
with pd.option_context('mode.use_inf_as_na', True):
  g = sns.catplot(
      data=new_df, kind="bar",
      x="Action Type", y="log(Frequency)", hue="Device",
      ci="sd", palette="dark", alpha=.6, height=8
  )
  g.set_axis_labels("", "Normalized Frequency")
  g.fig.suptitle('FREQUENCY DISTRIBUTION OF IMPRESSIONS, CONVERSIONS AND REFERRALS AS PER DEVICE')
# Out:
#      Device  Action Type  Frequency  log(Frequency)
# 0   Desktop  conversions        967        2.985426
# 1   Desktop  impressions   17824081        7.251007
# 2   Desktop    referrals     240850        5.381747
# 3    Mobile  conversions        788        2.896526
# 4    Mobile  impressions   38510851        7.585583
# 5    Mobile    referrals     343801        5.536307
# 6    Tablet  conversions        299        2.475671
# 7    Tablet  impressions   10306191        7.013098
# 8    Tablet    referrals     144311        5.159299
# 9     Other  conversions          0            -inf
# 10    Other  impressions        142        2.152288
# 11    Other    referrals          0            -inf

# %% [markdown]
# # Calculations using original frequency

# %% [markdown]
# #Mobile:
#
# * Referrals per 1000 impressions = (343801 / 38510851) * 1000 = 8.927
#
# * Conversion per 1000 impressions = (788 / 38510851 ) * 1000 = 0.020
#
# * Conversions per 1000 referrals = (788 / 343801) * 1000 = 2.29
#
# #Desktop:
#
# * Referrals per 1000 impressions = (240850  /  17824081)*1000 = 13.5
#
# * Conversions per 1000 impressions = (967 / 17824081 ) * 1000 = 0.050
#
# * Conversions per 1000 referrals = (967 / 240850) * 1000 = 4.01
#
# #Tablet:
#
# * Referrals per 1000 impressions =  (144311 / 10306191) * 1000 = 14.00
#
# * Conversions per 1000 impressions = (299 / 10306191 ) * 1000 = 0.029
#
# * Conversions per 1000 referrals = (299 / 144311 ) * 1000 = 2.07

# %% [markdown]
# From the graph above we can infer following conclusions:
#
#
# * Conversions to impressions ratio is high for Desktop device. Desktop visitors contribute for biggest portion of revenue for the company.
#
# * There are no any referrals from Other devices. The Other devices are increasing the cost with no any contribution in revenue.
#
# * Referrals to impressions ratio is high for Tablet device and low for mobile device. That is the reach of ad to target users  are least for mobile devices and high for Tablet devices.
#
# * Conversions to referalls ratio is high for Desktop and least for Mobile. That is the most ad visitors from Mobile don't want what you are offering them. But, the ad visitors from the Desktop is liking the offering from ad.

# %% [markdown]
# #Recommendations:
#
# 1. Boost up the impressions on Desktop devices. Since, they they have highest contribution in the conversions of target audience.
# 2. Focus on sending the impressions of Mobile device to potential users. Ad_unit_id might be responsible for the attraction of users.
#
# 2. Focus on seeing the ad by target audience for Other device. Ad unit might responsible for it.
#
# 3. Focus on offering made to the ad visitor for Mobile device. Creative unit id might be responsible for it.

# %% [markdown]
# ## Let's visualize the relationship between creative id and conversions for each device type.

# %% [markdown]
# #Firstly, let's define a function that takes type of device as an argument and returns DataFrame required.

# %%
def conversion_vs_creative(device):
  df_conversion_vs_creative_df = df[df['device'] == device]
  df_conversion_vs_creative_df =  df_conversion_vs_creative_df.groupby(["creative_id"], as_index=False)["conversions"].sum()
  df_conversion_vs_creative_df.plot(x = 'creative_id', y = 'conversions',kind ='bar', figsize = (20,8),rot = 0, title = 'Conversions Vs creative id when devices used  were' + str(device))
  plt.ylabel('Conversions') 
  return df_conversion_vs_creative_df

# %% [markdown]
# 1. **Conversions Vs creative id when Desktop Devices were used**

# %%
desktop_obj_cvc = conversion_vs_creative("Desktop") #Function call

# %% [markdown]
# We can see that, for Desktop Devices, creative id's 10 , 11, 12, 54 and 55 only have contribution in conversions. Creative id 10 has highest number of conversions. creative id's 11 and 12 have very less conversions. So, I recommend not using those creative id's which have less number of conversions and excluding those which don't have any conversions at all.

# %% [markdown]
# 2.  **Conversions Vs creative id when Mobile Devices were used**

# %%
Mobile_obj_cvc = conversion_vs_creative('Mobile') #Function call

# %% [markdown]
# We can see that, for Mobile Devices, creative id's 6, 10, 11, 12, 49,50,58 only have contribution in conversions. Creative id 10 has highest number of conversions. Creative id's 11 and 12 has very less conversions. So, I recommend not using those creative id's which have less number of conversions and excluding those which don't have any conversions at all.
#
#
#
# ---

# %% [markdown]
# 3.  **Conversions Vs creative id when Tablet Devices were used**

# %%
Tablet_obj_cvc = conversion_vs_creative('Tablet')

# %% [markdown]
# We can see that, for Tablet Devices, creative id's 1, 3, 6, 10, 11,55 ,57 ,58 only have contribution in conversions. Creative id 1 has highest number of conversions. Creative id's 11, 55 and 58 has less number of conversions. So, I recommend not using those creative id's which have less number of conversions and excluding those which don't have any conversions at all.

# %% [markdown]
# # Lets visualize a combine graph for conversions vs creative_id corresponding to the each device type.

# %%
# Visualization
plt.figure(figsize=(20,10))
plt.plot(desktop_obj_cvc['creative_id'], desktop_obj_cvc['conversions'] , label = 'Desktop')
plt.plot(Tablet_obj_cvc['creative_id'], Tablet_obj_cvc['conversions'] , label = 'Tablet', color ='black')
plt.plot(Mobile_obj_cvc['creative_id'], Mobile_obj_cvc['conversions'] , label = 'Mobile',color = 'red')
plt.title('Combined creative_id vs conversions graph corresponding to the device type used' )
plt.xlabel('creative_id')
plt.ylabel('Conversions')
plt.legend()

# %% [markdown]
# Note : *We can see that creative id 10 is very useful. It has conversions for all three devices.*

# %% [markdown]
# WE CAN USE THE ABOVE GRAPH IF WE NEED SIMULTANEOUS COMPARISON OF CREATIVE ID'S FOR EACH DEVICES WITH RESPECT TO NUMBER OF  CONVERSIONS.

# %% [markdown]
# #Let's visualize conversions vs ad_unit_id for each type of devices.

# %% [markdown]
# #Let's define a function first that takes Type of device as argument and returns a DataFrame

# %% [markdown]
# First, Let's remove "Organic" from ad_unit_id.

# %%
org_removed_df = df[df.ad_unit_id != 'Organic']

# %%
def Conversions_ad_unit_id(device):
  df_conversions_ad_unit_id = org_removed_df[org_removed_df['device'] == device]
  df_conversions_ad_unit_id =  df_conversions_ad_unit_id.groupby(["ad_unit_id"], as_index=False)["conversions"].sum()
  df_conversions_ad_unit_id.plot(x = 'ad_unit_id', y = 'conversions',kind ='bar', figsize = (20,8),rot = 0, title = 'Conversions Vs ad_unit_id when devices used  were' + str(device))
  plt.ylabel('Conversions') 
  return df_conversions_ad_unit_id

# %% [markdown]
#  1. **Conversions vs ad_unit_id when Desktop devices were used**

# %%
Desktop_conversions_vs_ad_obj = Conversions_ad_unit_id('Desktop') #Function call

# %% [markdown]
# **Let's split the ad_unit_id into two parts visualize more clearly below:**
#
# *Note: For the more precise view we can either view the graph in a larger screen or split ad_unit_id in more number of parts.*

# %% [markdown]
# **Let's define another function that plots graph for ad_unit_id more than 600:**

# %%
def more_than_600_conv_ad(device_conversions_vs_ad_obj):
    # Creating a new data frame
    device_conversions_vs_ad_obj= device_conversions_vs_ad_obj[(device_conversions_vs_ad_obj['ad_unit_id'].astype(int)> 600)]
    # Visualization
    plt.figure()
    device_conversions_vs_ad_obj.plot(x = 'ad_unit_id', y = 'conversions', figsize = (20,10), title = 'COnversions Vs ad_unit_id(more than 600)')
    plt.ylabel('Conversions')

# %% [markdown]
# **Let's define another function that plots graph for ad_unit_id less than 600**

# %%
def less_than_600_conv_ad(device_conversions_vs_ad_obj):
    # Creating a new data frame
    device_conversions_vs_ad_obj= device_conversions_vs_ad_obj[(device_conversions_vs_ad_obj['ad_unit_id'].astype(int)< 600)]
    # Visualization
    plt.figure()
    device_conversions_vs_ad_obj.plot(x = 'ad_unit_id', y = 'conversions', figsize = (20,10), title = 'COnversions Vs ad_unit_id(less than 600)')
    plt.ylabel('Conversions')

# %% [markdown]
# 1.1 **When ad_unit_id is more than 600 for Desktop Devices.**

# %%
more_than_600_conv_ad(Desktop_conversions_vs_ad_obj)

# %% [markdown]
# We can see that ad unit id around 614, 755 and 942 have large contribution in conversions for Mobile Devices users. I recommend using those ad_unit_id's to boost up the revenue. I also recommend to filter the ad_unit_id which doesn't have any contribution at all, from the above graph.

# %% [markdown]
# 1.2 **When ad_unit_id is less than 600**

# %%
less_than_600_conv_ad(Desktop_conversions_vs_ad_obj)

# %% [markdown]
# We can see that ad unit id around 160, 195, 250, 555 have large contribution in conversions for Desktop Devices users. I recommend using those ad_unit_id's to boost up the revenue. I also recommend to filter the ad_unit_id which doesn't have any contribution at all, from the above graph.

# %% [markdown]
#  2. **Conversions vs ad_unit_id when Mobile devices were used**

# %%
Mobile_conversions_vs_ad_obj = Conversions_ad_unit_id('Mobile') #Function call

# %% [markdown]
# **Let's visualize more clearly below.**

# %% [markdown]
# 2.1 **When the ad unit id is more than 600 for Mobile Devices**

# %%
more_than_600_conv_ad(Mobile_conversions_vs_ad_obj)

# %% [markdown]
# We can see that ad unit id around 635 and between ( 755, 800 ), 944, 935 have large contribution in conversions for Mobile Devices users. I recommend using those ad_unit_id's to boost up the revenue. I also recommend to filter the ad_unit_id which don't have any contribution at all from the above graph.

# %% [markdown]
# 2.2 **When ad_unit_id is less than 600 for Mobile devices**

# %%
less_than_600_conv_ad(Mobile_conversions_vs_ad_obj)

# %% [markdown]
# We can see that ad unit id around 555, 67, 294 have more contribution in conversions for Mobile Devices users. I recommend using those ad_unit_id's to boost up the revenue. I also recommend to filter the ad_unit_id which don't have any contribution at all from the above graph.

# %% [markdown]
#  3. **Conversions vs ad_unit_id when Tablet devices were used**

# %%
Tablet_conversions_vs_ad_obj = Conversions_ad_unit_id('Tablet') #Function call

# %% [markdown]
# **Let's split ad_unit_id into two parts and visualize more clearly below:**

# %% [markdown]
# 3.1 **When ad_unit_id is less than 600 for Tablet Devices**

# %%
less_than_600_conv_ad(Tablet_conversions_vs_ad_obj)

# %% [markdown]
# We can see that ad unit id around 614, 755, 860 have more contribution in conversions for Tablet Devices users. I recommend using those ad_unit_id's to boost up the revenue. I also recommend to filter the ad_unit_id which don't have any contribution at all from the above graph.

# %% [markdown]
# 3.2 **When ad_unit_id is more than 600 for Tablet Devices**

# %%
more_than_600_conv_ad(Tablet_conversions_vs_ad_obj)

# %% [markdown]
# We can see that ad unit id around 147, 250, 555 have more contribution in conversions for Tablet Devices users. I recommend using those ad_unit_id's to boost up the revenue. I also recommend to filter the ad_unit_id which don't have any contribution at all from the above graph.

# %% [markdown]
# #Let's visualize ad_unit_id and referrals according to the device type used.

# %% [markdown]
# #Firstly define a function that takes device type as an argument and returns a DataFrame.

# %%
def Referrals_ad_unit_id(device):
  df_Referrals_ad_unit_id = org_removed_df[org_removed_df['device'] == device]
  df_Referrals_ad_unit_id =  df_Referrals_ad_unit_id.groupby(["ad_unit_id"], as_index=False)["referrals"].sum()
  df_Referrals_ad_unit_id.plot(x = 'ad_unit_id', y = 'referrals',kind ='bar', figsize = (20,8),rot = 0, title = 'Referrals Vs ad_unit_id when devices used  were' + str(device))
  plt.ylabel('Referrals') 
  return df_Referrals_ad_unit_id

# %% [markdown]
# **Let's define another function that plots graph for ad_unit_id more than 600:**

# %%
def more_than_600_ref_ad(device_conversions_vs_ref_obj):
    # Creating a new data frame
    device_conversions_vs_ref_obj= device_conversions_vs_ref_obj[(device_conversions_vs_ref_obj['ad_unit_id'].astype(int)> 600)]
    # Visualization
    plt.figure()
    device_conversions_vs_ref_obj.plot(x = 'ad_unit_id', y = 'referrals', figsize = (20,10), title = 'Referrals Vs ad_unit_id(more than 600)')
    plt.ylabel('Referrals')

# %% [markdown]
# **Let's define another function that plots graph for ad_unit_id less than 600**

# %%
def less_than_600_ref_ad(device_conversions_vs_ref_obj):
    # Creating a new data frame
    device_conversions_vs_ref_obj= device_conversions_vs_ref_obj[(device_conversions_vs_ref_obj['ad_unit_id'].astype(int)< 600)]
    # Visualization
    plt.figure()
    device_conversions_vs_ref_obj.plot(x = 'ad_unit_id', y = 'referrals', figsize = (20,10), title = 'Referrals Vs ad_unit_id(less than 600)')
    plt.ylabel('Referrals')

# %% [markdown]
#  1. **Referrals vs ad_unit_id when Desktop devices were used**

# %%
Referrals_ad_unit_Desktop_obj = Referrals_ad_unit_id('Desktop')

# %% [markdown]
# **Let's visualize more clearly below splitting ad_unit_id into two parts:**

# %% [markdown]
# 1.1 **When ad_unit_id is more than 600 for Desktop devices**

# %%
more_than_600_ref_ad(Referrals_ad_unit_Desktop_obj)

# %% [markdown]
# We can see that ad unit id around 614, 755, 930, 950 have large contribution in referrals for Desktop Devices users. I recommend using those ad_unit_id's to boost up the
# referral rate. I also recommend to filter the ad_unit_id which don't have any contribution in referrals at all from the above graph.

# %% [markdown]
# 1.2 **When ad_unit_id is less than 600 for Desktop Devices**

# %%
less_than_600_ref_ad(Referrals_ad_unit_Desktop_obj)

# %% [markdown]
# We can see that ad unit id around 160, 170, 245, 555 to have large contribution in referrals for Desktop Devices users. I recommend using those ad_unit_id's to boost up the
# referral rate. I also recommend to filter the ad_unit_id which don't have any contribution in referrals at all from the above graph.

# %% [markdown]
#  2. **Referrals vs ad_unit_id when Mobile devices were used**

# %%
Referrals_ad_unit_Mobile_obj = Referrals_ad_unit_id('Mobile')

# %% [markdown]
# **Let's split the ad_unit_id into two parts and visualize more clearly below:**

# %% [markdown]
# 2.1 **When ad_unit_id is more than 600 for Mobile Devices**

# %%
more_than_600_ref_ad(Referrals_ad_unit_Mobile_obj)

# %% [markdown]
# We can see that ad unit id around 626, 650 and 875 have large contribution in referrals for Mobile Devices users. I recommend using those ad_unit_id's to boost up the
# referral rate. I also recommend to filter the ad_unit_id which don't have any contribution in referrals at all from the above graph.

# %% [markdown]
# 2.2 **When ad_unit_id is less than 600 for Mobile devices**

# %%
less_than_600_ref_ad(Referrals_ad_unit_Mobile_obj)

# %% [markdown]
# We can see that ad unit id around 140, 555, 67, 294 have large contribution in referrals for Mobile Devices users. I recommend using those ad_unit_id's to boost up the
# referral rate. I also recommend to filter the ad_unit_id which don't have any contribution in referrals at all from the above graph.

# %% [markdown]
#  3. **Referrals vs ad_unit_id when Tablet devices were used**

# %%
Referrals_ad_unit_Tablet_obj = Referrals_ad_unit_id('Tablet')

# %% [markdown]
# **Let's split the ad_unit_id into two parts and visualize more clearly**

# %% [markdown]
# 3.1 **When ad_unit_id is more than 600 for Tablet devices**

# %%
more_than_600_ref_ad(Referrals_ad_unit_Tablet_obj)

# %% [markdown]
# We can see that ad unit id around 620, 755, 970 have large contribution in referrals for Tablet Devices users. I recommend using those ad_unit_id's to boost up the
# referral rate. I also recommend to filter the ad_unit_id which don't have any contribution in referrals at all from the above graph.

# %% [markdown]
# 3.2 **When ad_unit_id is less than 600 for Tablet Devices**

# %%
less_than_600_ref_ad(Referrals_ad_unit_Tablet_obj)

# %% [markdown]
# We can see that ad unit id around 259 have large contribution in referrals for Tablet Devices users. I recommend using those ad_unit_id's to boost up the
# referral rate. I also recommend to filter the ad_unit_id which don't have any contribution in referrals at all from the above graph.

# %% [markdown]
# # Let's visualize Conversions, Referrals and Impressions according to the date.

# %%
# Creation of new DataFrame
new_df_rows1 = []
for date in df['date'].unique():
  rows = df[df['date'] == date]
  total_conversions = rows['conversions'].sum()
  total_impressions = rows['impressions'].sum()
  total_referrals  = rows['referrals'].sum()
  new_df_rows1.append([date,'conversions',total_conversions])
  new_df_rows1.append([date,'impressions',total_impressions])
  new_df_rows1.append([date,'referrals',total_referrals])

# Normalization of frequency, using logarithmic function, for clear visibility of graph 
new_df1 = pd.DataFrame(new_df_rows1, columns=['Date', 'Action Type', 'Frequency'])
new_df1['log(Frequency)'] = np.log10(new_df1['Frequency'])
print(new_df1)

# Visualization
import seaborn as sns
sns.set_theme(style="whitegrid")


g = sns.catplot(
    data=new_df1, kind="bar",
    x="Date", y="log(Frequency)", hue="Action Type",
    ci="sd", palette="dark", alpha=.6, height=10, aspect = 2
)
g.despine(left=True)
g.set_axis_labels("Date from 2018/1/1 to 2018/1/31", "Frequency")
g.legend.set_title("")
# Out:
#          Date  Action Type  Frequency  log(Frequency)
# 0  2017-11-01  conversions         90        1.954243
# 1  2017-11-01  impressions    2274962        6.356974
# 2  2017-11-01    referrals      29399        4.468333
# 3  2017-11-02  conversions         70        1.845098
# 4  2017-11-02  impressions    2097621        6.321727
# ..        ...          ...        ...             ...
# 85 2017-11-29  impressions    2384282        6.377358
# 86 2017-11-29    referrals      28444        4.453991
# 87 2017-11-30  conversions         50        1.698970
# 88 2017-11-30  impressions    1938040        6.287363
# 89 2017-11-30    referrals      22295        4.348207
#
# [90 rows x 4 columns]

# %% [markdown]
# WE CAN USE THE ABOVE GRAPH FOR VISUALIZATION OF NUMBER OF CONVERSIONS, IMPRESSIONS AND REFERRALS WITH RESPECT TO EACH DATES.

# %% [markdown]
# #SET OF METRICS

# %% [markdown]
# #CONVERSION RATE PER REFERRAL(CRR)

# %% [markdown]
# How many ad visitors were actually converted?

# %% [markdown]
# **Conversion rate per referral(CRR) = (Total Conversions / Total referrals) * 100%**

# %%
CRR = (df['conversions'].sum() / df['referrals'].sum()*100)
print('The conversion rate  = ',CRR, '%')
# Out:
# The conversion rate  =  0.2817705175304062 %

# %% [markdown]
# Out of 1000 ad visitors,  about 3 of them were converted.

# %% [markdown]
# #CONVERSION RATE PER IMPRESSION(CVR)

# %% [markdown]
# HOW MANY IMPRESSIONS WERE ACTUALLY CONVERTED?

# %% [markdown]
# **Conversion rate per 1000 impressions ( CVRI ) = ( Total Conversions / Total impressions )  * 1000**

# %%
CVRI = (df['conversions'].sum() / df['impressions'].sum())*1000
print('Conversion rate per 1000 impressions is = ', CVRI)
# Out:
# Conversion rate per 1000 impressions is =  0.030821743854952333

# %% [markdown]
# #REFERRAL RATE PER IMPRESSION (RRI)

# %% [markdown]
# HOW MANY IMPRESSIONS WERE CLICKED AND THE AD WAS VISITED BY THE USER?

# %% [markdown]
# **Referral rate per 1000 impressions ( RRI ) = ( Total referrals / Total impressions ) * 1000**

# %%
RRI = (df['referrals'].sum() / df['impressions'].sum())*1000
print('Referrals rate  per 1000 impressions  = ', RRI)
# Out:
# Referrals rate  per 1000 impressions  =  10.938597879256944

# %% [markdown]
# #COST PER MILE (CPM)

# %% [markdown]
# How much Company is paying publisher per 1,000 impressions?

# %% [markdown]
# **Cost Per Mile (CPM)  = ( publisher split / impressions ) * 1000**

# %%
CPM = (df['publisher_split'] * 1000).divide(df['impressions'])
with pd.option_context('mode.use_inf_as_na', True):
  print('The average value of money Company is paying publisher per 1000 impressions is = $',CPM.dropna().mean())
# Out:
# The average value of money Company is paying publisher per 1000 impressions is = $ 1.264360212239908

# %% [markdown]
# The average value of money Company is paying publisher per 1000 impressions is = $ 1.264360212239908

# %%
# Visualization
CPM.dropna().plot.hist(bins=100,figsize = (10,5), title = ' Frequency Distribution of COST PER MILE(CPM)')

# %% [markdown]
# We can see the frequency of cost per mile is higher between 0 and 5.

# %%
with pd.option_context('mode.use_inf_as_na', True):
  CPM.dropna().plot.density(figsize = (10,5), xlim = (-25,25), title = 'Density ditribution of CPM')

# %% [markdown]
# # REVENUE PER MILE(RPM)
#
# ---
#
#
#
# ---

# %% [markdown]
# How much advertiser is paying company per 1000 impressions?

# %% [markdown]
# **Revenue Per Mile ( RPM ) = $ ( conversions / impressions ) *1000 *65 (as of 1/31)**
#
# **Revenue Per Mile (RPM) = $ (conversions / impressions ) *1000 *60.50 ( through 1/30 )**

# %%
# Creation of new Data Frame splitting the dates
on_jan31_df= df[(df['date'] == '2018-01-31')]
before_jan31_df= df[(df['date'] < '2018-01-31')]
RPM1 = (on_jan31_df['conversions']* 65*1000).divide(on_jan31_df['impressions'])
RPM2 = (before_jan31_df['conversions']* 60.50*1000).divide(before_jan31_df['impressions'])

# Concatenation
RPM = pd.concat([RPM2,RPM1])

# %%
with pd.option_context('mode.use_inf_as_na', True):
  print('The average value of money advertiser is paying company per 1000 impressions is = $',RPM.dropna().mean())
# Out:
# The average value of money advertiser is paying company per 1000 impressions is = $ 3.379491390662628

# %% [markdown]
# The average value of money advertiser is paying the company per 1000 impressions is = $ 3.379491390662628

# %%
# Visualization
with pd.option_context('mode.use_inf_as_na', True):
  RPM.dropna().plot.density(figsize = (10,5), xlim = (-200,500), title = 'Density distribution of REVENUE PER MILE(RPM)')

# %% [markdown]
# #PROFIT PER MILE(PPM)
# Note : Staff and other operating expenses is not included

# %% [markdown]
# **PROFIT PER MILE (PPM) = REVENUE PER MILE (RPM) - COST PER MILE (CPM)**

# %%
# Calculation
PPM = RPM - CPM
with pd.option_context('mode.use_inf_as_na', True): 
   print('The average value of PPM without including staff and other operating expenses is = $',PPM.dropna().mean())
# Out:
# The average value of PPM without including staff and other operating expenses is = $ 2.115131178422638

# %%
#Visualization of PPM
with pd.option_context('mode.use_inf_as_na', True):
  PPM.dropna().plot.density(figsize = (10,5), xlim = (-200,1000), title ='Density distribution of Profit Per Mile(PPM)')

# %% [markdown]
# # Creating a new data table including PPM CPM and RPM

# %%
# Creation of new data table
analysis_df = pd.concat([RPM,CPM,PPM],axis=1)
analysis_df.columns= ["RPM","CPM","PPM"]
with pd.option_context('mode.use_inf_as_na', True):
  print(analysis_df.dropna().describe())
merged_df = pd.concat([df,analysis_df], axis =1)
merged_df.dropna(0)
# Out:
#                  RPM            CPM            PPM
# count  131911.000000  131911.000000  131911.000000
# mean        3.379491       1.264360       2.115131
# std       269.502968       1.406338     269.505477
# min         0.000000       0.000000     -20.000000
# 25%         0.000000       0.483871      -1.749030
# 50%         0.000000       0.909091      -0.909091
# 75%         0.000000       1.764706      -0.441176
# max     60500.000000      20.000000   60500.000000
#              date   device  creative_id  ...  RPM       CPM       PPM
# 0      2017-11-01  Desktop            6  ...  0.0  7.826087 -7.826087
# 1      2017-11-01  Desktop           54  ...  0.0  7.936508 -7.936508
# 2      2017-11-01  Desktop           55  ...  0.0  8.013029 -8.013029
# 3      2017-11-01  Desktop           10  ...  0.0  8.008299 -8.008299
# 4      2017-11-01   Mobile            6  ...  0.0  3.003145 -3.003145
# ...           ...      ...          ...  ...  ...       ...       ...
# 134616 2017-11-30   Tablet           10  ...  0.0  0.000000  0.000000
# 134617 2017-11-30   Tablet            6  ...  0.0  0.000000  0.000000
# 134618 2017-11-30   Tablet            6  ...  0.0  0.000000  0.000000
# 134619 2017-11-30   Tablet            1  ...  0.0  0.000000  0.000000
# 134620 2017-11-30   Tablet           57  ...  0.0  0.000000  0.000000
#
# [131911 rows x 11 columns]

# %% [markdown]
# **WHAT IS THE TOTAL COST OF THE COMPANY FOR THE WHOLE MONTH?**

# %% [markdown]
# Note : Operating cost and other expenses are not included.

# %%
weighted_sum_cost = (merged_df['CPM'].multiply(merged_df['impressions']/1000)).sum()
print(weighted_sum_cost)
# Out:
# 75378.70999999999

# %% [markdown]
# The total money paid by Company to Publisher for whole Month is (TOTAL COST) = $ 75378.70999999999

# %% [markdown]
# **WHAT IS THE TOTAL REVENUE OF THE COMPANY FOR THE WHOLE MONTH?**
#
# ---

# %%
weighted_sum_revenue = (merged_df['RPM'].multiply(merged_df['impressions']/1000)).sum()
print(weighted_sum_revenue)
# Out:
# 123964.5

# %% [markdown]
# The total money advertiser is paying the company(Total Revenue) for whole month is = $ 123964.5

# %% [markdown]
# **WHAT IS THE TOTAL PROFIT OF THE COMPANY FOR THE WHOLE MONTH?**

# %% [markdown]
# NOTE: Operating cost and other expenses are not included.

# %%
weighted_sum_profit = (merged_df['PPM'].multiply(merged_df['impressions']/1000)).sum()
print(weighted_sum_profit)
# Out:
# 48585.79000000001

# %% [markdown]
# The total sum of profit earned by company(excluding operating cost and other expenses) for whole Month is = $ 48585.79000000001

# %% [markdown]
# #RPM Vs Dates Visualization

# %%
# Visualization
plt.figure(figsize=(15,10))
dates = matplotlib.dates.date2num(df['date'])
plt.plot_date(merged_df['date'], merged_df['RPM'], linestyle = '-')
pl.suptitle('Date vs Revenue Per Mile(RPM)', fontsize=16)
pl.xlabel('Dates')
pl.ylabel('Revenue Per Mile')
# Out:
# Text(0, 0.5, 'Revenue Per Mile')

# %% [markdown]
# From the above graph we can see that 11th and 26th of the month has highest amount of Revenue Per Mile.

# %% [markdown]
# # PPM vs Impressions Graph

# %%
# Visualization
merged_df.plot(kind = 'scatter',x = 'impressions' , y = 'PPM', figsize = (20,10) , title = 'Profit per mile (PPM) vs impressions')
plt.ylim(0,200)
plt.xlim(0,30000)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# (0.0, 30000.0)

# %% [markdown]
# As the number of impressions is increasing the PPM is decreasing. This shows that they are negatively correlated. This is due to the reason that less amount of impressions are being converted and which is decreasing revenue and increasing the cost. We need to optimize the impressions to increase revenue.

# %% [markdown]
# Let us convert PPM, CPM and RPM in the data table into  Profit,  Cost and Revenue respectively

# %%
merged_df.loc[:,'PPM'] *= (merged_df['impressions']/1000)
merged_df.loc[:,'CPM'] *= (merged_df['impressions']/1000)
merged_df.loc[:,'RPM'] *= (merged_df['impressions']/1000)

# %% [markdown]
# #Let's plot Profit VS creative_id graph according to device type used

# %% [markdown]
# **Let's define a function first**

# %%
def Creative_id_profit(device):
  df_Creative_id_profit = merged_df[merged_df['device'] == device]
  df_Creative_id_profit =  df_Creative_id_profit.groupby(["creative_id"], as_index=False)["PPM"].sum()
  df_Creative_id_profit.plot(x = 'creative_id', y = 'PPM',kind ='bar', figsize = (20,8),rot = 0, title = 'Profit Vs creative id when devices used  were' + str(device))
  plt.ylabel('Profit') 
  return df_Creative_id_profit

# %% [markdown]
# 1. **Creative_id vs Profit when Desktop devices were used**

# %%
Desktop_creative_id_profit = Creative_id_profit('Desktop')

# %% [markdown]
# Creative id's 11, 12 and 50 have either very low profit or loss.

# %% [markdown]
# 2. **Creative_id vs Profit when Mobile devices were used**

# %%
Mobile_creative_id_profit = Creative_id_profit('Mobile')

# %% [markdown]
# Creative id's 7 and 12 has either very small profit or loss.

# %% [markdown]
# 3. **Creative_id vs Profit when Tablet devices were used**

# %%
Tablet_creative_id_profit = Creative_id_profit('Tablet')

# %% [markdown]
# Creative id's 11 , 55 and 58 has very small amount of profit.

# %% [markdown]
# #Let's plot a combined graph for Creative id vs Profit according the device used.

# %%
#Visualization
plt.figure(figsize=(20,10))
plt.plot(Desktop_creative_id_profit['creative_id'], Desktop_creative_id_profit['PPM'] , label = 'Desktop')
plt.plot(Tablet_creative_id_profit['creative_id'], Tablet_creative_id_profit['PPM'] , label = 'Tablet')
plt.plot(Mobile_creative_id_profit['creative_id'], Mobile_creative_id_profit['PPM'] , label = 'Mobile')
plt.legend()
plt.title('Combined Profit vs creative_id graph corresponding to the device types used')
plt.xlabel('creative_id')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# #Visualization of Profit VS Ad_unit_id corresponding to the device used

# %% [markdown]
# #Firstly define a function that takes device type as an argument and returns a DataFrame containing necessary information.

# %%
organic_removed_merged_df = merged_df[merged_df.ad_unit_id != 'Organic']

# %%
def Profit_ad_unit_id(device):
  df_Profit_ad_unit_id = organic_removed_merged_df[organic_removed_merged_df['device'] == device]
  df_Profit_ad_unit_id =  df_Profit_ad_unit_id.groupby(["ad_unit_id"], as_index=False)["PPM"].sum()
  df_Profit_ad_unit_id.plot(x = 'ad_unit_id', y = 'PPM',kind ='bar', figsize = (20,8),rot = 0, title = 'Profit Vs creative id when devices used  were' + str(device))
  plt.ylabel('Profit') 
  return df_Profit_ad_unit_id

# %% [markdown]
# 1. **Profit vs ad_unit_id when Mobile device was used**

# %%
Mobile_Profit_ad_unit_id = Profit_ad_unit_id('Mobile')

# %% [markdown]
# The visualization is not that much clear. So, let's split the ad_unit_id into two parts and plot the graph.

# %% [markdown]
# **Let's define another function that plots graph for ad_unit_id more than 600:**

# %%
def more_than_600_Profit_ad(device_revenue_vs_ad_df):
    # Creating a new data frame
    device_revenue_vs_ad_df= device_revenue_vs_ad_df[(device_revenue_vs_ad_df['ad_unit_id'].astype(int)> 600)]
    # Visualization
    plt.figure()
    device_revenue_vs_ad_df.plot(x = 'ad_unit_id', y = 'PPM', figsize = (20,10), title = 'Profit Vs ad_unit_id(more than 600)')
    plt.ylabel('Revenue')

# %%
def less_than_600_Profit_ad(device_revenue_vs_ad_df):
    # Creating a new data frame
    device_revenue_vs_ad_df= device_revenue_vs_ad_df[(device_revenue_vs_ad_df['ad_unit_id'].astype(int)< 600)]
    # Visualization
    plt.figure()
    device_revenue_vs_ad_df.plot(x = 'ad_unit_id', y = 'PPM', figsize = (20,10), title = 'Profit Vs ad_unit_id(less than 600)')
    plt.ylabel('Revenue')

# %% [markdown]
# 1.1 **For ad_unit_it less than 600**

# %%
less_than_600_Profit_ad(Mobile_Profit_ad_unit_id)

# %% [markdown]
# 1.2 **For ad_unit_id more than 600**

# %%
more_than_600_Profit_ad(Mobile_Profit_ad_unit_id)

# %% [markdown]
# 2. **Profit vs ad_unit_id when Desktop device was used**

# %%
Desktop_Profit_ad_unit_id = Profit_ad_unit_id('Desktop')

# %% [markdown]
# 2.1 **For ad_unit_it less than 600**

# %%
less_than_600_Profit_ad(Desktop_Profit_ad_unit_id)

# %% [markdown]
# 2.2 **For ad_unit_id more than 600**

# %%
more_than_600_Profit_ad(Desktop_Profit_ad_unit_id)

# %% [markdown]
# 3. **Profit vs ad_unit_id when Tablet device was used**

# %%
Tablet_Profit_ad_unit_id = Profit_ad_unit_id('Tablet')

# %% [markdown]
# 3.1 **For ad_unit_it less than 600**

# %%
less_than_600_Profit_ad(Tablet_Profit_ad_unit_id)

# %% [markdown]
# 3.2 **For ad_unit_id more than 600**

# %%
more_than_600_Profit_ad(Tablet_Profit_ad_unit_id)

# %% [markdown]
# #Visualization of Total profit vs Dates as per the Devices used by Users.

# %% [markdown]
# #Let's define a function first

# %%
def Profit_date(device):
  df_Profit_date = merged_df[merged_df['device'] == device]
  df_Profit_date =  df_Profit_date.groupby(["date"], as_index=False)["PPM"].sum()
  df_Profit_date['date'] = df_Profit_date['date'].dt.date
  df_Profit_date.plot(x = 'date', y = 'PPM',kind ='bar', figsize = (20,8), title = 'Profit Vs Dates when devices used  were' + str(device))
  plt.ylabel('Profit') 
  return df_Profit_date

# %% [markdown]
# 1. **Total profit Vs Dates when Mobile Devices were used by users**

# %%
profit_date_Mobile_df = Profit_date('Mobile')

# %% [markdown]
# From the above graph we can see that, when the device used by users is Mobile , company has highest profit on 6th of the month and with no loss.

# %% [markdown]
# 2. **Total Profit VS dates when Desktop Devices were used by Users**

# %%
profit_date_Desktop_df = Profit_date('Desktop')

# %% [markdown]
# From the above graph we can see that, when the device used by users is Desktop , company has highest profit on 3rd of the month and no any loss.

# %% [markdown]
# 3. **Total profit Vs Dates when Tablet devices were used by users.**

# %%
profit_date_Tablet_df = Profit_date('Tablet')

# %% [markdown]
# From the above graph we can see that, when the device used by users is Tablet , company has highest profit on 26th of the month and loss on 20th.

# %% [markdown]
# #Lets plot combined Profit Vs Date graph corresponding to the device type used.

# %%
#Visualization
plt.figure(figsize=(20,10))
plt.plot(profit_date_Desktop_df['date'], profit_date_Desktop_df['PPM'] , label = 'Desktop')
plt.plot(profit_date_Tablet_df['date'], profit_date_Tablet_df['PPM'] , label = 'Tablet')
plt.plot(profit_date_Mobile_df['date'], profit_date_Mobile_df['PPM'] , label = 'Mobile')
plt.legend()
plt.title('Combined Profit vs Date graph corresponding to the device types used')
plt.xlabel('Date')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# From the above graph, we can infer that, in most of the dates, Desktop devices are responsible for high amount of profit.

# %% [markdown]
# # Let's plot Total Cost vs Dates corresponding to the device types used by users.

# %% [markdown]
# **Let's define a function first**

# %%
def Cost_date(device):
  df_Cost_date = merged_df[merged_df['device'] == device]
  df_Cost_date =  df_Cost_date.groupby(["date"], as_index=False)["CPM"].sum()
  df_Cost_date['date'] = df_Cost_date['date'].dt.date
  df_Cost_date.plot(x = 'date', y = 'CPM',kind ='bar', figsize = (20,8), title = 'Cost Vs Dates when devices used  were' + str(device))
  plt.ylabel('Profit') 
  return df_Cost_date

# %% [markdown]
# 1. **When Mobile devices were used by users.**

# %%
Cost_date_Mobile_df = Cost_date('Mobile')

# %% [markdown]
# The money paid to the publisher by the company is highest on 25th of the month and lowest on 23rd of the month when Mobile Devices were used by users.

# %% [markdown]
# 2. **When Desktop Devices were used by users.**

# %%
Cost_date_Desktop_df = Cost_date('Desktop')

# %% [markdown]
# The money paid to the publisher by the company is highest on 6th of the month and lowest on 19th of the month when Desktop Devices were used by users.

# %% [markdown]
# 3. **When Tablet Devices were used by users**

# %%
Cost_date_Tablet_df = Cost_date('Tablet')

# %% [markdown]
# The money paid to the publisher by the company is highest on 30th of the month and lowest on 3rd of the month when Tablet Devices were used by users.

# %% [markdown]
# # Let's plot combined cost vs date Graph for Corresponding devices

# %%
# Visualization
plt.figure(figsize=(20,10))
plt.plot(Cost_date_Desktop_df['date'], Cost_date_Desktop_df['CPM'] , label = 'Desktop')
plt.plot(Cost_date_Tablet_df['date'], Cost_date_Tablet_df['CPM'] , label = 'Tablet')
plt.plot(Cost_date_Mobile_df['date'], Cost_date_Mobile_df['CPM'] , label = 'Mobile')
plt.title('Combinded Cost vs Date graph Corresponding to the device type used' )
plt.legend()
plt.xlabel('Date')
plt.ylabel('Cost')
# Out:
# Text(0, 0.5, 'Cost')

# %% [markdown]
# #Let's plot Revenue vs dates according the device used by users.

# %% [markdown]
# **Let's define a function first**

# %%
def Revenue_date(device):
  df_Revenue_date = merged_df[merged_df['device'] == device]
  df_Revenue_date =  df_Revenue_date.groupby(["date"], as_index=False)["RPM"].sum()
  df_Revenue_date['date'] = df_Revenue_date['date'].dt.date
  df_Revenue_date.plot(x = 'date', y = 'RPM',kind ='bar', figsize = (20,8), title = 'Revenue Vs Dates when devices used  were' + str(device))
  plt.ylabel('Profit') 
  return df_Revenue_date

# %% [markdown]
# 1.**Revenue vs dates when desktop devices were used by users.**

# %%
Desktop_revenue_date = Revenue_date('Desktop')

# %% [markdown]
# We can see that on 6th the revenue was high as per the Desktop devices were used by users.

# %% [markdown]
# 2.**Revenue vs date when Mobile devices were used by users.**

# %%
Mobile_revenue_date = Revenue_date('Mobile')

# %% [markdown]
# We can see that maximum revenue is on 6th and lowest on 23rd.

# %% [markdown]
# 3. **Revenue vs date when Tablet devices were used by users.**

# %%
Tablet_revenue_date = Revenue_date('Tablet')

# %% [markdown]
# We can see that maximum revenue is on 26th and lowest on 20th.

# %%
# Visualization
plt.figure(figsize=(20,10))
plt.plot(Desktop_revenue_date['date'], Desktop_revenue_date['RPM'] , label = 'Desktop')
plt.plot(Tablet_revenue_date['date'], Tablet_revenue_date['RPM'] , label = 'Tablet')
plt.plot(Mobile_revenue_date['date'], Mobile_revenue_date['RPM'] , label = 'Mobile')
plt.title('Combined Revenue vs Date graph corresponding to the device type used' )
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.legend()

# %% [markdown]
# #Let's visualize  Revenue vs ad_unit_id Graph corresponding to the device type used.

# %% [markdown]
# #Let's define a function first.

# %%
def Revenue_ad_unit_id(device):
  df_Revenue_ad_unit_id = organic_removed_merged_df[organic_removed_merged_df['device'] == device]
  df_Revenue_ad_unit_id =  df_Revenue_ad_unit_id.groupby(["ad_unit_id"], as_index=False)["RPM"].sum()
  df_Revenue_ad_unit_id.plot(x = 'ad_unit_id', y = 'RPM',kind ='bar', figsize = (20,8),rot = 0, title = 'Revenue Vs ad_unit_id when devices used  were' + str(device))
  plt.ylabel('Revenue') 
  return df_Revenue_ad_unit_id

# %% [markdown]
# 1. **Revenue vs ad_unit_id when Mobile device was used**

# %%
Mobile_revenue_ad_unit_id = Revenue_ad_unit_id('Mobile')

# %% [markdown]
# The visualization is not that much clear. So, let's split the ad_unit_id into two parts and plot the graph.

# %% [markdown]
# **Let's define another function that plots graph for ad_unit_id more than 600:**

# %%
def more_than_600_rev_ad(device_revenue_vs_ad_df):
    # Creating a new data frame
    device_revenue_vs_ad_df= device_revenue_vs_ad_df[(device_revenue_vs_ad_df['ad_unit_id'].astype(int)> 600)]
    # Visualization
    plt.figure()
    device_revenue_vs_ad_df.plot(x = 'ad_unit_id', y = 'RPM', figsize = (20,10), title = 'Revenue Vs ad_unit_id(more than 600)')
    plt.ylabel('Revenue')

# %% [markdown]
# **Let's define another function that plots graph for ad_unit_id less than 600**

# %%
def less_than_600_rev_ad(device_revenue_vs_ad_df):
    # Creating a new data frame
    device_revenue_vs_ad_df= device_revenue_vs_ad_df[(device_revenue_vs_ad_df['ad_unit_id'].astype(int)< 600)]
    # Visualization
    plt.figure()
    device_revenue_vs_ad_df.plot(x = 'ad_unit_id', y = 'RPM', figsize = (20,10), title = 'Revenue Vs ad_unit_id(less than 600)')
    plt.ylabel('Revenue')

# %% [markdown]
# 1.1 **When ad_unit_id is more than 600 for Mobile Devices**

# %%
more_than_600_rev_ad(Mobile_revenue_ad_unit_id)

# %% [markdown]
# Now, we can see that ad_unit_id around 620, 770, 924, 930 has more contribution in the revenue. The company should exclude the use of ad_unit_id which has no any contribution is revenue.

# %% [markdown]
# 1.2  **When ad_unit_id is less than 600 for Mobile Devices**

# %%
less_than_600_rev_ad(Mobile_revenue_ad_unit_id)

# %% [markdown]
# We can see that ad_unit_id's around 555, 245, 294 have very high contribution in the Revenue of the company. So we can includ those id's excluding others looking at the graph.

# %% [markdown]
# 2. **Revenue Vs ad_unit_id for Desktop devices**

# %%
Desktop_revenue_ad_unit_id = Revenue_ad_unit_id('Desktop')

# %% [markdown]
# Let's split the ad_unit_id's into two parts and make the visualization more clear.

# %% [markdown]
# _NOTE : The ad_unit_id's can be splitted into more parts or can be viewed in the larger screen for precise conclusions._

# %% [markdown]
# 2.1 **For ad_unit_id's more than 600.**

# %%
more_than_600_rev_ad(Desktop_revenue_ad_unit_id)

# %% [markdown]
# We can see that the revenue is high  when the ad_unit_id is around 614, 755 and 924 for Desktop devices.

# %% [markdown]
# 2.2 **When ad_unit_id is less than 600 for Desktop devices.**

# %%
less_than_600_rev_ad(Desktop_revenue_ad_unit_id)

# %% [markdown]
# Ad unit id's around 160, around 195, 555 to 67  is increasing the revenue from Desktop device users. So company should focus on using them more for Desktop devices. I recommend company to avoid the ad_unit_id's which don't havd any contribution in revenue.

# %% [markdown]
# ## 3. Revenue vs ad_unit_id graph when Tablet devices were used

# %%
Tablet_revenue_ad_unit_id = Revenue_ad_unit_id('Tablet')

# %% [markdown]
# Let's visualize more clearly splitting the ad_unit_id into two parts.

# %% [markdown]
# 3.1 **When ad_unit id is more than 600**

# %%
more_than_600_rev_ad(Tablet_revenue_ad_unit_id)

# %% [markdown]
# We can see that ad_unit_id's around 614, 755, 687, 924, 813 is increasing the revenue for from Tablet device users. So, I recommend using those ad_unit_id's and excluding non-contributing ad_unit_id's for tablet devices looking at the above graph.

# %% [markdown]
# 3.2 **When the ad_unit_id is less than 600.**

# %%
less_than_600_rev_ad(Tablet_revenue_ad_unit_id)

# %% [markdown]
# We can see that ad_unit_id's around 195, 250, 555 is increasing the revenue for from Tablet device users. So, I recommend using those ad_unit_id's and excluding non-contributing ad_unit_id's inferring from above graph.

# %% [markdown]
# #Let's plot Revenue Vs creative_id graph corresponding to the Device Type

# %% [markdown]
# #Let's define a function first

# %%
def Creative_id_Revenue(device):
  df_Creative_id_Revenue = merged_df[merged_df['device'] == device]
  df_Creative_id_Revenue =  df_Creative_id_Revenue.groupby(["creative_id"], as_index=False)["RPM"].sum()
  df_Creative_id_Revenue.plot(x = 'creative_id', y = 'RPM',kind ='bar', figsize = (20,8),rot = 0, title = 'Revenue Vs creative id when devices used  were' + str(device))
  plt.ylabel('Revenue') 
  return df_Creative_id_Revenue

# %% [markdown]
# 1. **Revenue Vs creative_id when device type is Desktop.**

# %%
Desktop_creative = Creative_id_Revenue('Desktop')

# %% [markdown]
# We can see that for the Desktop device the revenue is high when creative id is 10,11,12,54,55 Company can boost up the revenue using those creative id for Desktop devices. So, I recommend not using those creative id's which have less number of conversions and excluding those which don't have any conversions at all.

# %% [markdown]
# 2. **Revenue Vs creative_id when device type is Mobile.**

# %%
Mobile_Creative = Creative_id_Revenue('Mobile')

# %% [markdown]
# From the above graph, for Mobile device, we can see that for creative id 6,10,11,12,49,50 and 58 have most contribution in the revenue of the company. So using those creative id's, in Mobile Devices, can boost up the revenue of the company. 11 and 12 creative id's has less number of conversions. So, I recommend not using those creative id's which have less number of conversions and excluding those which don't have any conversions at all.

# %% [markdown]
# 3. **Revenue Vs creative_id when device type is Tablet.**

# %%
Tablet_creative = Creative_id_Revenue('Tablet')

# %% [markdown]
# From the above graph we can see the creative_id 1, 3,6,10,11,55,57 and 58 has highest contribution in revenue. We can use those creative_id , for Tablet devices ,inorder to boost up the revenue. Creative id's 11,55 and 58 has very less number of conversions. So, I recommend not using those creative id's which have less number of conversions and excluding those which don't have any conversions at all.

# %%
# Visualization
plt.figure(figsize=(20,10))
plt.plot(Desktop_creative['creative_id'], Desktop_creative['RPM'] , label = 'Desktop')
plt.plot(Tablet_creative['creative_id'], Tablet_creative['RPM'] , label = 'Tablet', color ='black')
plt.plot(Mobile_Creative['creative_id'], Mobile_Creative['RPM'] , label = 'Mobile',color = 'red')
plt.title('Combined creative_id vs revenue graph corresponding to the device type used' )
plt.xlabel('creative_id')
plt.ylabel('Revenue')
plt.legend()
